# %%
import gymnasium as gym

import gym_super_mario_bros

print(gym.__all__)

print(gym.envs.__all__)

from nes_py.wrappers import JoypadSpace #A
# from gym_super_mario_bros import
# Out:
# ['Env', 'Wrapper', 'ObservationWrapper', 'ActionWrapper', 'RewardWrapper', 'Space', 'make', 'make_vec', 'spec', 'register', 'registry', 'VectorizeMode', 'pprint_registry', 'register_envs', 'envs', 'spaces', 'utils', 'vector', 'wrappers', 'error', 'logger', 'experimental']
# ['make', 'pprint_registry', 'register', 'registry', 'spec']

# %%
import gym_super_mario_bros

[x for x in dir(gym_super_mario_bros) if not x.startswith('_')]
# Out:
# ['MarioTask',
#  'SMB3Stage',
#  'SuperMarioBros2Env',
#  'SuperMarioBros3Env',
#  'SuperMarioBrosEnv',
#  'all_tasks',
#  'make',
#  'smb2_env',
#  'smb3_env',
#  'smb3_stage_matrix',
#  'smb3_stages',
#  'smb_env',
#  'task_for_env_id',
#  'task_ids',
#  'tasks']

# %%
help(gym_super_mario_bros.make)
# Out:
# Help on function make in module gymnasium.envs.registration:
#
# make(
#     id: str | EnvSpec,
#     max_episode_steps: int | None = None,
#     disable_env_checker: bool | None = None,
#     **kwargs: Any
# ) -> Env
#     Creates an environment previously registered with :meth:`gymnasium.register` or a :class:`EnvSpec`.
#
#     To find all available environments use ``gymnasium.envs.registry.keys()`` for all valid ids.
#
#     Args:
#         id: A string for the environment id or a :class:`EnvSpec`. Optionally if using a string, a module to import can be included, e.g. ``'module:Env-v0'``.
#             This is equivalent to importing the module first to register the environment followed by making the environment.
#         max_episode_steps: Maximum length of an episode, can override the registered :class:`EnvSpec` ``max_episode_steps``
#             with the value being passed to :class:`gymnasium.wrappers.TimeLimit`.
# ...

# %% [markdown]
# dir() shows names,  \
# help() / ? shows how to call them, \
# ?? shows the source. \
# For most tasks these three are enough.

# %%
import gym_super_mario_bros
print(gym_super_mario_bros.__file__)
# Out:
# /home/CNS2026014739/miniconda3/envs/torch/lib/python3.14/site-packages/gym_super_mario_bros/__init__.py
